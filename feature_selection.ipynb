# %%
# install imbalance lib
! pip install -q imbalanced-learn==0.5.0

# %%
import pandas as pd
import numpy as np
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
# Out:
# Using TensorFlow backend.
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# ## Read in data
# The first(A) is one with all variables with >5% missing values removed, the second(B) is imputed form the most recent complete data-point prior to that birth and the third(C) is imputed using mode values
#
# Derived variables are:
# - _cohort – Either 1 (born in the first deriving cohort) or 0 (in the second, testing cohort)
# - _hie – 1 for HIE, 0 for not
# - _id
# - _lapgar – 1 for a low Apgar score, 0 for not
# - _ne – Another measure of brain injury (not used at present)
# - _neonataldeath – Not used at present
# - _perinataldeath – 1 for perinatal death; 0 for not
# - _resus – 1 for resus at birth, and 0 for not
# - _stillborn – Not used at present
# - _yearofbirth -  Year of birth
#
# First letter is either a (antenatal), g (growth) or I (intrapartum) variable
# Second letter is type of entry; c (categorical), o(ordinal) or l(linear)
# Then _NAME (most have one given)
# Then _#### - number of were extraction was performed on the [Variable File]("3. Index_Variable File_304.2ADV3A.pdf")

# %%
def split_data(df, x_cols, y_col):
    x = df[x_cols + [y_col]]
    x = x.dropna(axis='index')
    y = x.pop(y_col)
    return x, y

def resample(train_x, train_y):
    # over sample minority class
    train_x_resampled, train_y_resampled = SMOTE(random_state=0).fit_resample(train_x, train_y)
    train_x_resampled = pd.DataFrame(train_x_resampled, columns=train_x.columns)
    train_y_resampled = pd.DataFrame(train_y_resampled, columns=[train_y.name])
    
    return train_x_resampled, train_y_resampled

def rf_feature_select_threshold(X, y, threshold=0.01):
    clf = RandomForestClassifier(random_state=0, n_estimators=100)
    clf = clf.fit(X.values, y.values.ravel())
    fi = pd.DataFrame(data={'predictor' : X.columns, 'feature_importance': clf.feature_importances_})
    return X.columns[clf.feature_importances_ > threshold]

def standardize_continuous_values(df, continuous_features, means, stds):
    for i, f in enumerate(continuous_features):
        if f in df.columns:
            df[f] = (df[f] - means[i]) / stds[i]
    return df

# %%
# read in data from DO
dat = pd.read_stata("data/1_2_3_4A._Done.dta")

# %%
# collect cat cols
categorical = []
for col in dat.columns:
    if col[0] == "_":
        continue
    if col[1] == "c":
        categorical.append(col)

# convert unordered categorical to dummy
for c in categorical:
    one_hot = pd.get_dummies(dat[c], prefix=c)
    dat = pd.concat([dat, one_hot], axis=1)
    dat = dat.drop(c, axis=1)

# %%
# sep cols
antenatal = []
antenatal_growth = []
antenatal_intrapartum = []
categorical = []
ordinal = []
linear = []

for col in dat.columns:
    if col[0] == "_":
        continue
    if col[0] == "a":
        antenatal.append(col)
        antenatal_growth.append(col)
        antenatal_intrapartum.append(col)
    if col[0] == "g":
        antenatal_growth.append(col)
    if col[0] == "i":
        antenatal_intrapartum.append(col)
    if col[1] == "c":
        categorical.append(col)
    if col[1] == "o":
        ordinal.append(col)
    if col[1] == "l":
        linear.append(col)

# %%
# split test and train
test = dat[dat['_cohort'] == 0]
train = dat[dat['_cohort'] == 1]

## get mean and SD for **training** dataset to standardise variables
desc = train[linear + ordinal].describe()
means = np.array(desc.T['mean'])
stds = np.array(desc.T['std'])

# %%
for name, variable_list in {"antenatal" : antenatal, "antenatal_growth" : antenatal_growth, "antenatal_intrapartum" : antenatal_intrapartum}.items():
    for outcome in ['_hie', '_lapgar', '_perinataldeath', '_resus']:
        print("Working on {} for {}".format(name, outcome))
        
        # select variables for this analysis
        train_x, train_y = split_data(train, variable_list, outcome)
        test_x, test_y = split_data(test, variable_list, outcome)
        
        # resample the minor class
        train_x, train_y = resample(train_x, train_y)
        
        # identify highly correlated features
        corr_matrix = train_x.corr().abs()
        upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
        to_drop = [column for column in upper.columns if any(upper[column] > 0.8)]
        
        # drop one highly correlated feature from a pair
        print("Dropping correlated features: {}".format(to_drop))
        train_x = train_x.drop(to_drop, axis=1)
        test_x = test_x.drop(to_drop, axis=1)

        # feature selection using random forest
        keep = rf_feature_select_threshold(train_x, train_y)
        print("Selected features: {}".format(list(keep)))
        train_x = train_x[keep]
        test_x = test_x[keep]
        
        # standardize continuous values
        train_x = standardize_continuous_values(train_x, linear + ordinal, means, stds)
        test_x = standardize_continuous_values(test_x, linear + ordinal, means, stds)

        # write to csv
        pd.concat([train_x, train_y], axis=1).to_csv("data/{}{}_train.csv".format(name, outcome), header=True)
        pd.concat([test_x, test_y], axis=1).to_csv("data/{}{}_test.csv".format(name, outcome), header=True)
# Out:
# Working on antenatal for _hie
# Dropping correlated features: ['al_magecat_0033', 'al_mweightfinal_0341', 'ao_fagecat_0376', 'ao_mdbp_0337', 'ao_meducationcat_0272', 'ao_mhctlow_0092', 'ao_mincomecat_0275', 'ao_msbp_0332', 'ao_msescat_0296', 'ao_mweightgain_0320', 'ao_personssupported_0360', 'ao_personssupportedcat_0362', 'ao_plurality_0009', 'ac_antenataldisease_0308_8.0', 'ac_antenataldisease_0309_8.0', 'ac_antenataldisease_0310_0.0', 'ac_antenataldisease_0310_8.0', 'ac_breech_1347_7.0', 'ac_breech_1348_0.0', 'ac_breech_1348_1.0', 'ac_breech_1348_6.0', 'ac_breech_1348_7.0', 'ac_breech_1350_0.0', 'ac_breech_1351_0.0', 'ac_breech_1351_1.0', 'ac_breech_1352_0.0', 'ac_breech_1352_7.0', 'ac_breech_1352_8.0', 'ac_cigperday_0054_1.0', 'ac_consang_0287_8.0', 'ac_consang_0288_0.0', 'ac_consang_0288_8.0', 'ac_consang_0290_0.0', 'ac_consang_0292_0.0', 'ac_consang_0292_1.0', 'ac_fatherathome_0373_0.0', 'ac_fatherathome_0373_1.0', 'ac_fatherathome_0381_0.0', 'ac_fatherathome_0381_1.0', 'ac_fhneurology_0410_0.0', 'ac_fhneurology_0410_8.0', 'ac_fhneurology_0411_0.0', 'ac_fhneurology_0411_8.0', 'ac_fhneurology_0412_0.0', 'ac_fhneurology_0412_8.0', 'ac_fhneurology_0429_0.0', 'ac_fhneurology_0429_8.0', 'ac_fhneurology_0430_0.0', 'ac_fhneurology_0430_8.0', 'ac_fhneurology_0431_0.0', 'ac_fhneurology_0431_8.0', 'ac_fhseizures_0286_0.0', 'ac_fhseizures_0286_8.0', 'ac_fhx_0396_88.0', 'ac_fhx_0398_8.0', 'ac_fhx_0399_0.0', 'ac_fhx_0399_8.0', 'ac_fhx_0400_8.0', 'ac_fhx_0401_7.0', 'ac_fhx_0401_8.0', 'ac_fhx_0402_8.0', 'ac_fhx_0403_8.0', 'ac_fhx_0404_8.0', 'ac_fhx_0405_0.0', 'ac_fhx_0405_8.0', 'ac_fhx_0406_0.0', 'ac_fhx_0406_8.0', 'ac_fhx_0407_0.0', 'ac_fhx_0407_8.0', 'ac_fhx_0408_0.0', 'ac_fhx_0408_8.0', 'ac_fhx_0415_0.0', 'ac_fhx_0415_8.0', 'ac_fhx_0416_0.0', 'ac_fhx_0416_8.0', 'ac_fhx_0417_8.0', 'ac_fhx_0418_0.0', 'ac_fhx_0418_8.0', 'ac_fhx_0419_0.0', 'ac_fhx_0419_8.0', 'ac_fhx_0420_0.0', 'ac_fhx_0420_8.0', 'ac_fhx_0421_0.0', 'ac_fhx_0421_8.0', 'ac_fhx_0422_0.0', 'ac_fhx_0422_8.0', 'ac_fhx_0423_0.0', 'ac_fhx_0423_8.0', 'ac_fhx_0424_0.0', 'ac_fhx_0424_8.0', 'ac_fhx_0425_0.0', 'ac_fhx_0425_8.0', 'ac_fhx_0426_0.0', 'ac_fhx_0426_8.0', 'ac_fhx_0427_0.0', 'ac_fhx_0427_8.0', 'ac_fhx_0432_0.0', 'ac_fhx_0432_1.0', 'ac_fhx_0432_2.0', 'ac_fhx_0432_8.0', 'ac_fhx_0433_0.0', 'ac_fhx_0433_1.0', 'ac_fhx_0433_2.0', 'ac_fhx_0433_3.0', 'ac_fhx_0433_5.0', 'ac_fhx_0433_6.0', 'ac_fhx_0433_8.0', 'ac_fhx_0434_3.0', 'ac_fhx_0434_5.0', 'ac_fhx_0434_7.0', 'ac_fhx_0434_8.0', 'ac_fhx_0435_0.0', 'ac_fhx_0435_1.0', 'ac_fhx_0435_3.0', 'ac_fhx_0435_7.0', 'ac_fhx_0435_8.0', 'ac_fhx_0436_0.0', 'ac_fhx_0436_1.0', 'ac_fhx_0436_2.0', 'ac_fhx_0436_4.0', 'ac_fhx_0436_8.0', 'ac_fhx_0437_0.0', 'ac_fhx_0437_1.0', 'ac_fhx_0437_2.0', 'ac_fhx_0437_3.0', 'ac_fhx_0437_4.0', 'ac_fhx_0437_5.0', 'ac_fhx_0437_8.0', 'ac_fhx_0438_0.0', 'ac_fhx_0438_6.0', 'ac_fhx_0438_7.0', 'ac_fhx_0438_8.0', 'ac_fhx_0439_0.0', 'ac_fhx_0439_2.0', 'ac_fhx_0439_4.0', 'ac_fhx_0439_6.0', 'ac_fhx_0439_8.0', 'ac_fhx_0440_0.0', 'ac_fhx_0440_8.0', 'ac_fhx_0441_0.0', 'ac_fhx_0441_1.0', 'ac_fhx_0441_2.0', 'ac_fhx_0441_3.0', 'ac_fhx_0441_4.0', 'ac_fhx_0441_5.0', 'ac_fhx_0441_8.0', 'ac_fhx_0442_0.0', 'ac_fhx_0442_1.0', 'ac_fhx_0442_2.0', 'ac_fhx_0442_3.0', 'ac_fhx_0442_8.0', 'ac_fhx_0443_0.0', 'ac_fhx_0443_1.0', 'ac_fhx_0443_2.0', 'ac_fhx_0443_8.0', 'ac_fhx_0444_0.0', 'ac_fhx_0444_2.0', 'ac_fhx_0444_3.0', 'ac_fhx_0444_8.0', 'ac_fhx_0445_0.0', 'ac_fhx_0445_2.0', 'ac_fhx_0445_8.0', 'ac_fhx_0446_0.0', 'ac_fhx_0446_88.0', 'ac_fhx_0448_1.0', 'ac_fhx_0448_8.0', 'ac_fhx_0448_10.0', 'ac_fhx_0448_11.0', 'ac_fhx_0448_15.0', 'ac_fhx_0448_16.0', 'ac_fhx_0448_88.0', 'ac_fhx_0450_7.0', 'ac_fhx_0450_8.0', 'ac_fhx_0451_0.0', 'ac_fhx_0451_8.0', 'ac_fhx_0452_0.0', 'ac_fhx_0452_8.0', 'ac_fhx_0453_0.0', 'ac_fhx_0453_1.0', 'ac_fhx_0453_8.0', 'ac_fhx_0454_0.0', 'ac_fhx_0454_8.0', 'ac_fhx_0455_0.0', 'ac_fhx_0455_8.0', 'ac_fhx_0456_0.0', 'ac_fhx_0456_8.0', 'ac_fhx_0457_0.0', 'ac_fhx_0457_8.0', 'ac_fhx_0458_0.0', 'ac_fhx_0458_8.0', 'ac_fhx_0459_0.0', 'ac_fhx_0459_8.0', 'ac_fhx_0460_0.0', ...
# Selected features: ['al_parity_0046', 'ac_breech_1349_0.0', 'ac_cigperday_0054_0.0', 'ac_fhx_0401_1.0', 'ac_fhx_0402_0.0', 'ac_foccupationcat_0387_2.0', 'ac_foccupationcat_0387_3.0', 'ac_lastpreg_0038_7.0', 'ac_mabnormalhr_0495_0.0', 'ac_mbirthplace_0278_1.0', 'ac_mbloodgroup_0344_1.0', 'ac_mdisease_0104_0.0', 'ac_mdisease_0105_7.0', 'ac_mdisease_0138_0.0', 'ac_mdisease_0188_0.0', 'ac_mdisease_0251_0.0', 'ac_mdisease_0258_1.0', 'ac_mdisease_0266_2.0', 'ac_presentation_1321_11.0', 'ac_presentationcat_1324_1.0', 'ac_race_0303_1', 'ac_radiologicix_0074_0.0', 'ac_sex_0554_1.0']
# Working on antenatal for _lapgar
# Dropping correlated features: ['al_magecat_0033', 'al_mweightfinal_0341', 'ao_fagecat_0376', 'ao_mdbp_0337', 'ao_meducationcat_0272', 'ao_mhctlow_0092', 'ao_mincomecat_0275', 'ao_msbp_0332', 'ao_msescat_0296', 'ao_mweightgain_0320', 'ao_personssupportedcat_0362', 'ao_plurality_0009', 'ac_antenataldisease_0308_8.0', 'ac_antenataldisease_0309_8.0', 'ac_antenataldisease_0310_0.0', 'ac_antenataldisease_0310_8.0', 'ac_breech_1347_7.0', 'ac_breech_1348_0.0', 'ac_breech_1348_1.0', 'ac_breech_1348_6.0', 'ac_breech_1348_7.0', 'ac_breech_1350_0.0', 'ac_breech_1351_0.0', 'ac_breech_1351_4.0', 'ac_breech_1352_0.0', 'ac_breech_1352_1.0', 'ac_breech_1352_7.0', 'ac_breech_1352_8.0', 'ac_cigperday_0054_1.0', 'ac_consang_0287_8.0', 'ac_consang_0288_0.0', 'ac_consang_0288_8.0', 'ac_consang_0289_8.0', 'ac_consang_0290_0.0', 'ac_consang_0292_0.0', 'ac_fatherathome_0373_0.0', 'ac_fatherathome_0373_1.0', 'ac_fatherathome_0381_0.0', 'ac_fatherathome_0381_1.0', 'ac_fhneurology_0410_0.0', 'ac_fhneurology_0410_8.0', 'ac_fhneurology_0411_0.0', 'ac_fhneurology_0411_8.0', 'ac_fhneurology_0412_0.0', 'ac_fhneurology_0412_8.0', 'ac_fhneurology_0429_0.0', 'ac_fhneurology_0429_8.0', 'ac_fhneurology_0430_0.0', 'ac_fhneurology_0430_8.0', 'ac_fhneurology_0431_0.0', 'ac_fhneurology_0431_8.0', 'ac_fhseizures_0286_0.0', 'ac_fhseizures_0286_8.0', 'ac_fhx_0396_88.0', 'ac_fhx_0398_8.0', 'ac_fhx_0399_0.0', 'ac_fhx_0399_8.0', 'ac_fhx_0400_8.0', 'ac_fhx_0401_8.0', 'ac_fhx_0402_8.0', 'ac_fhx_0403_8.0', 'ac_fhx_0404_8.0', 'ac_fhx_0405_0.0', 'ac_fhx_0405_8.0', 'ac_fhx_0406_0.0', 'ac_fhx_0406_8.0', 'ac_fhx_0407_0.0', 'ac_fhx_0407_8.0', 'ac_fhx_0408_0.0', 'ac_fhx_0408_8.0', 'ac_fhx_0415_0.0', 'ac_fhx_0415_8.0', 'ac_fhx_0416_0.0', 'ac_fhx_0416_8.0', 'ac_fhx_0417_8.0', 'ac_fhx_0418_0.0', 'ac_fhx_0418_8.0', 'ac_fhx_0419_0.0', 'ac_fhx_0419_8.0', 'ac_fhx_0420_0.0', 'ac_fhx_0420_8.0', 'ac_fhx_0421_0.0', 'ac_fhx_0421_8.0', 'ac_fhx_0422_0.0', 'ac_fhx_0422_8.0', 'ac_fhx_0423_0.0', 'ac_fhx_0423_8.0', 'ac_fhx_0424_0.0', 'ac_fhx_0424_8.0', 'ac_fhx_0425_0.0', 'ac_fhx_0425_8.0', 'ac_fhx_0426_0.0', 'ac_fhx_0426_8.0', 'ac_fhx_0427_0.0', 'ac_fhx_0427_8.0', 'ac_fhx_0432_0.0', 'ac_fhx_0432_1.0', 'ac_fhx_0432_2.0', 'ac_fhx_0432_3.0', 'ac_fhx_0432_4.0', 'ac_fhx_0432_8.0', 'ac_fhx_0433_0.0', 'ac_fhx_0433_1.0', 'ac_fhx_0433_2.0', 'ac_fhx_0433_3.0', 'ac_fhx_0433_5.0', 'ac_fhx_0433_6.0', 'ac_fhx_0433_8.0', 'ac_fhx_0434_1.0', 'ac_fhx_0434_3.0', 'ac_fhx_0434_5.0', 'ac_fhx_0434_7.0', 'ac_fhx_0434_8.0', 'ac_fhx_0435_0.0', 'ac_fhx_0435_5.0', 'ac_fhx_0435_7.0', 'ac_fhx_0435_8.0', 'ac_fhx_0436_0.0', 'ac_fhx_0436_1.0', 'ac_fhx_0436_2.0', 'ac_fhx_0436_4.0', 'ac_fhx_0436_8.0', 'ac_fhx_0437_1.0', 'ac_fhx_0437_2.0', 'ac_fhx_0437_3.0', 'ac_fhx_0437_4.0', 'ac_fhx_0437_5.0', 'ac_fhx_0437_8.0', 'ac_fhx_0438_0.0', 'ac_fhx_0438_7.0', 'ac_fhx_0438_8.0', 'ac_fhx_0439_0.0', 'ac_fhx_0439_1.0', 'ac_fhx_0439_4.0', 'ac_fhx_0439_6.0', 'ac_fhx_0439_8.0', 'ac_fhx_0440_0.0', 'ac_fhx_0440_1.0', 'ac_fhx_0440_2.0', 'ac_fhx_0440_8.0', 'ac_fhx_0441_0.0', 'ac_fhx_0441_1.0', 'ac_fhx_0441_2.0', 'ac_fhx_0441_3.0', 'ac_fhx_0441_4.0', 'ac_fhx_0441_5.0', 'ac_fhx_0441_8.0', 'ac_fhx_0442_0.0', 'ac_fhx_0442_1.0', 'ac_fhx_0442_2.0', 'ac_fhx_0442_3.0', 'ac_fhx_0442_8.0', 'ac_fhx_0443_0.0', 'ac_fhx_0443_1.0', 'ac_fhx_0443_2.0', 'ac_fhx_0443_8.0', 'ac_fhx_0444_0.0', 'ac_fhx_0444_1.0', 'ac_fhx_0444_2.0', 'ac_fhx_0444_3.0', 'ac_fhx_0444_8.0', 'ac_fhx_0445_0.0', 'ac_fhx_0445_8.0', 'ac_fhx_0446_0.0', 'ac_fhx_0446_1.0', 'ac_fhx_0446_88.0', 'ac_fhx_0448_8.0', 'ac_fhx_0448_10.0', 'ac_fhx_0448_11.0', 'ac_fhx_0448_15.0', 'ac_fhx_0448_16.0', 'ac_fhx_0448_88.0', 'ac_fhx_0450_7.0', 'ac_fhx_0450_8.0', 'ac_fhx_0451_0.0', 'ac_fhx_0451_8.0', 'ac_fhx_0452_0.0', 'ac_fhx_0452_8.0', 'ac_fhx_0453_0.0', 'ac_fhx_0453_8.0', 'ac_fhx_0454_0.0', 'ac_fhx_0454_8.0', 'ac_fhx_0455_0.0', 'ac_fhx_0455_8.0', 'ac_fhx_0456_0.0', 'ac_fhx_0456_8.0', 'ac_fhx_0457_0.0', 'ac_fhx_0457_8.0', 'ac_fhx_0458_0.0', 'ac_fhx_0458_8.0', 'ac_fhx_0459_0.0', 'ac_fhx_0459_8.0', 'ac_fhx_0460_0.0', 'ac_f ...
# Selected features: ['ac_antenataldisease_0305_0.0', 'ac_antenataldisease_0307_0.0', 'ac_antenataldisease_0307_4.0', 'ac_antenataldisease_0309_0.0', 'ac_antenataldisease_0309_4.0', 'ac_antenataldisease_0311_0.0', 'ac_antenataldisease_0311_1.0', 'ac_cigperday_0054_0.0', 'ac_consang_0287_0.0', 'ac_foccupationcat_0387_2.0', 'ac_mabnormalhr_0495_0.0', 'ac_mbirthplace_0278_1.0', 'ac_mbloodgroup_0344_1.0', 'ac_mdisease_0104_0.0', 'ac_mdisease_0188_0.0', 'ac_mdisease_0261_0.0', 'ac_mdisease_0266_0.0', 'ac_presentation_1321_11.0', 'ac_presentation_1321_111.0', 'ac_presentationcat_1324_1.0', 'ac_sex_0554_1.0', 'ac_trimesteratregistration_0037_3.0']
# Working on antenatal for _perinataldeath
# Dropping correlated features: ['al_magecat_0033', 'al_mweightfinal_0341', 'ao_fagecat_0376', 'ao_mdbp_0337', 'ao_meducationcat_0272', 'ao_mhctlow_0092', 'ao_mincomecat_0275', 'ao_msbp_0332', 'ao_msescat_0296', 'ao_mweightgain_0320', 'ao_personssupportedcat_0362', 'ao_plurality_0009', 'ac_antenataldisease_0308_8.0', 'ac_antenataldisease_0310_0.0', 'ac_antenataldisease_0310_8.0', 'ac_breech_1347_7.0', 'ac_breech_1348_0.0', 'ac_breech_1348_1.0', 'ac_breech_1348_6.0', 'ac_breech_1348_7.0', 'ac_breech_1350_0.0', 'ac_breech_1351_0.0', 'ac_breech_1352_0.0', 'ac_breech_1352_7.0', 'ac_breech_1352_8.0', 'ac_cigperday_0054_1.0', 'ac_consang_0287_8.0', 'ac_consang_0288_0.0', 'ac_consang_0288_8.0', 'ac_consang_0290_0.0', 'ac_consang_0292_0.0', 'ac_fatherathome_0373_0.0', 'ac_fatherathome_0373_1.0', 'ac_fatherathome_0381_0.0', 'ac_fatherathome_0381_1.0', 'ac_fhneurology_0410_0.0', 'ac_fhneurology_0410_8.0', 'ac_fhneurology_0411_0.0', 'ac_fhneurology_0411_8.0', 'ac_fhneurology_0412_0.0', 'ac_fhneurology_0412_8.0', 'ac_fhneurology_0429_0.0', 'ac_fhneurology_0429_8.0', 'ac_fhneurology_0430_0.0', 'ac_fhneurology_0430_8.0', 'ac_fhneurology_0431_0.0', 'ac_fhneurology_0431_8.0', 'ac_fhseizures_0286_0.0', 'ac_fhseizures_0286_8.0', 'ac_fhx_0396_88.0', 'ac_fhx_0398_8.0', 'ac_fhx_0399_0.0', 'ac_fhx_0399_4.0', 'ac_fhx_0399_8.0', 'ac_fhx_0400_8.0', 'ac_fhx_0401_8.0', 'ac_fhx_0402_8.0', 'ac_fhx_0403_8.0', 'ac_fhx_0404_8.0', 'ac_fhx_0405_0.0', 'ac_fhx_0405_8.0', 'ac_fhx_0406_0.0', 'ac_fhx_0406_8.0', 'ac_fhx_0407_0.0', 'ac_fhx_0407_8.0', 'ac_fhx_0408_0.0', 'ac_fhx_0408_8.0', 'ac_fhx_0415_0.0', 'ac_fhx_0415_8.0', 'ac_fhx_0416_0.0', 'ac_fhx_0416_8.0', 'ac_fhx_0417_8.0', 'ac_fhx_0418_0.0', 'ac_fhx_0418_8.0', 'ac_fhx_0419_0.0', 'ac_fhx_0419_8.0', 'ac_fhx_0420_0.0', 'ac_fhx_0420_8.0', 'ac_fhx_0421_0.0', 'ac_fhx_0421_8.0', 'ac_fhx_0422_0.0', 'ac_fhx_0422_8.0', 'ac_fhx_0423_0.0', 'ac_fhx_0423_8.0', 'ac_fhx_0424_0.0', 'ac_fhx_0424_8.0', 'ac_fhx_0425_0.0', 'ac_fhx_0425_8.0', 'ac_fhx_0426_0.0', 'ac_fhx_0426_8.0', 'ac_fhx_0427_0.0', 'ac_fhx_0427_8.0', 'ac_fhx_0432_0.0', 'ac_fhx_0432_1.0', 'ac_fhx_0432_2.0', 'ac_fhx_0432_3.0', 'ac_fhx_0432_4.0', 'ac_fhx_0432_8.0', 'ac_fhx_0433_0.0', 'ac_fhx_0433_1.0', 'ac_fhx_0433_2.0', 'ac_fhx_0433_3.0', 'ac_fhx_0433_4.0', 'ac_fhx_0433_5.0', 'ac_fhx_0433_6.0', 'ac_fhx_0433_8.0', 'ac_fhx_0434_4.0', 'ac_fhx_0434_5.0', 'ac_fhx_0434_6.0', 'ac_fhx_0434_7.0', 'ac_fhx_0434_8.0', 'ac_fhx_0435_5.0', 'ac_fhx_0435_6.0', 'ac_fhx_0435_7.0', 'ac_fhx_0435_8.0', 'ac_fhx_0436_0.0', 'ac_fhx_0436_1.0', 'ac_fhx_0436_2.0', 'ac_fhx_0436_3.0', 'ac_fhx_0436_4.0', 'ac_fhx_0436_8.0', 'ac_fhx_0437_0.0', 'ac_fhx_0437_1.0', 'ac_fhx_0437_2.0', 'ac_fhx_0437_3.0', 'ac_fhx_0437_4.0', 'ac_fhx_0437_5.0', 'ac_fhx_0437_8.0', 'ac_fhx_0438_7.0', 'ac_fhx_0438_8.0', 'ac_fhx_0439_0.0', 'ac_fhx_0439_1.0', 'ac_fhx_0439_2.0', 'ac_fhx_0439_4.0', 'ac_fhx_0439_6.0', 'ac_fhx_0439_8.0', 'ac_fhx_0440_0.0', 'ac_fhx_0440_8.0', 'ac_fhx_0441_0.0', 'ac_fhx_0441_1.0', 'ac_fhx_0441_2.0', 'ac_fhx_0441_3.0', 'ac_fhx_0441_4.0', 'ac_fhx_0441_5.0', 'ac_fhx_0441_8.0', 'ac_fhx_0442_0.0', 'ac_fhx_0442_1.0', 'ac_fhx_0442_3.0', 'ac_fhx_0442_8.0', 'ac_fhx_0443_0.0', 'ac_fhx_0443_1.0', 'ac_fhx_0443_2.0', 'ac_fhx_0443_8.0', 'ac_fhx_0444_0.0', 'ac_fhx_0444_2.0', 'ac_fhx_0444_3.0', 'ac_fhx_0444_8.0', 'ac_fhx_0445_0.0', 'ac_fhx_0445_8.0', 'ac_fhx_0446_0.0', 'ac_fhx_0446_1.0', 'ac_fhx_0446_88.0', 'ac_fhx_0448_8.0', 'ac_fhx_0448_15.0', 'ac_fhx_0448_16.0', 'ac_fhx_0448_88.0', 'ac_fhx_0450_7.0', 'ac_fhx_0450_8.0', 'ac_fhx_0451_0.0', 'ac_fhx_0451_8.0', 'ac_fhx_0452_0.0', 'ac_fhx_0452_1.0', 'ac_fhx_0452_8.0', 'ac_fhx_0453_0.0', 'ac_fhx_0453_8.0', 'ac_fhx_0454_0.0', 'ac_fhx_0454_8.0', 'ac_fhx_0455_0.0', 'ac_fhx_0455_8.0', 'ac_fhx_0456_0.0', 'ac_fhx_0456_8.0', 'ac_fhx_0457_0.0', 'ac_fhx_0457_8.0', 'ac_fhx_0458_0.0', 'ac_fhx_0458_8.0', 'ac_fhx_0459_0.0', 'ac_fhx_0459_8.0', 'ac_fhx_0460_0.0', 'ac_fhx_0460_8.0', 'ac_fhx_0461_0.0', 'ac_fhx_0461_8.0', 'ac_fhx_0462_0.0', 'ac_fhx_0462_8.0', 'ac_fhx_0463_0.0', 'ac_fhx_046 ...
# Selected features: ['ac_antenataldisease_0305_0.0', 'ac_breech_1349_0.0', 'ac_foccupationcat_0387_3.0', 'ac_mabnormalhr_0495_0.0', 'ac_mdisease_0104_0.0', 'ac_mdisease_0105_0.0', 'ac_mdisease_0266_0.0', 'ac_mdisease_0266_1.0', 'ac_mdisease_0267_0.0', 'ac_presentation_1321_11.0', 'ac_presentationcat_1324_1.0', 'ac_radiologicix_0074_0.0', 'ac_sex_0554_1.0', 'ac_toxemia_1328_0.0', 'ac_vagbleeding_0339_0.0']
# Working on antenatal for _resus
# Dropping correlated features: ['al_magecat_0033', 'al_mweightfinal_0341', 'ao_fagecat_0376', 'ao_mdbp_0337', 'ao_meducationcat_0272', 'ao_mhctlow_0092', 'ao_mincomecat_0275', 'ao_msbp_0332', 'ao_msescat_0296', 'ao_mweightgain_0320', 'ao_personssupportedcat_0362', 'ao_plurality_0009', 'ac_antenataldisease_0308_8.0', 'ac_antenataldisease_0310_0.0', 'ac_antenataldisease_0310_8.0', 'ac_breech_1347_7.0', 'ac_breech_1348_0.0', 'ac_breech_1348_1.0', 'ac_breech_1348_6.0', 'ac_breech_1348_7.0', 'ac_breech_1350_0.0', 'ac_breech_1351_0.0', 'ac_breech_1352_0.0', 'ac_breech_1352_7.0', 'ac_breech_1352_8.0', 'ac_cigperday_0054_1.0', 'ac_consang_0287_8.0', 'ac_consang_0288_0.0', 'ac_consang_0288_8.0', 'ac_consang_0290_0.0', 'ac_consang_0292_0.0', 'ac_fatherathome_0373_0.0', 'ac_fatherathome_0373_1.0', 'ac_fatherathome_0381_0.0', 'ac_fatherathome_0381_1.0', 'ac_fhneurology_0410_0.0', 'ac_fhneurology_0410_8.0', 'ac_fhneurology_0411_0.0', 'ac_fhneurology_0411_8.0', 'ac_fhneurology_0412_0.0', 'ac_fhneurology_0412_8.0', 'ac_fhneurology_0429_0.0', 'ac_fhneurology_0429_8.0', 'ac_fhneurology_0430_0.0', 'ac_fhneurology_0430_8.0', 'ac_fhneurology_0431_0.0', 'ac_fhneurology_0431_8.0', 'ac_fhseizures_0286_0.0', 'ac_fhseizures_0286_8.0', 'ac_fhx_0396_88.0', 'ac_fhx_0398_8.0', 'ac_fhx_0399_0.0', 'ac_fhx_0399_8.0', 'ac_fhx_0400_8.0', 'ac_fhx_0401_8.0', 'ac_fhx_0402_8.0', 'ac_fhx_0403_8.0', 'ac_fhx_0404_8.0', 'ac_fhx_0405_0.0', 'ac_fhx_0405_8.0', 'ac_fhx_0406_0.0', 'ac_fhx_0406_8.0', 'ac_fhx_0407_0.0', 'ac_fhx_0407_8.0', 'ac_fhx_0408_0.0', 'ac_fhx_0408_8.0', 'ac_fhx_0415_0.0', 'ac_fhx_0415_8.0', 'ac_fhx_0416_0.0', 'ac_fhx_0416_8.0', 'ac_fhx_0417_8.0', 'ac_fhx_0418_0.0', 'ac_fhx_0418_8.0', 'ac_fhx_0419_0.0', 'ac_fhx_0419_8.0', 'ac_fhx_0420_0.0', 'ac_fhx_0420_8.0', 'ac_fhx_0421_0.0', 'ac_fhx_0421_8.0', 'ac_fhx_0422_0.0', 'ac_fhx_0422_8.0', 'ac_fhx_0423_0.0', 'ac_fhx_0423_8.0', 'ac_fhx_0424_0.0', 'ac_fhx_0424_8.0', 'ac_fhx_0425_0.0', 'ac_fhx_0425_8.0', 'ac_fhx_0426_0.0', 'ac_fhx_0426_8.0', 'ac_fhx_0427_0.0', 'ac_fhx_0427_8.0', 'ac_fhx_0432_0.0', 'ac_fhx_0432_1.0', 'ac_fhx_0432_2.0', 'ac_fhx_0432_3.0', 'ac_fhx_0432_4.0', 'ac_fhx_0432_6.0', 'ac_fhx_0432_8.0', 'ac_fhx_0433_0.0', 'ac_fhx_0433_1.0', 'ac_fhx_0433_2.0', 'ac_fhx_0433_3.0', 'ac_fhx_0433_5.0', 'ac_fhx_0433_6.0', 'ac_fhx_0433_8.0', 'ac_fhx_0434_1.0', 'ac_fhx_0434_7.0', 'ac_fhx_0434_8.0', 'ac_fhx_0435_0.0', 'ac_fhx_0435_1.0', 'ac_fhx_0435_3.0', 'ac_fhx_0435_5.0', 'ac_fhx_0435_7.0', 'ac_fhx_0435_8.0', 'ac_fhx_0436_0.0', 'ac_fhx_0436_1.0', 'ac_fhx_0436_2.0', 'ac_fhx_0436_4.0', 'ac_fhx_0436_8.0', 'ac_fhx_0437_1.0', 'ac_fhx_0437_2.0', 'ac_fhx_0437_3.0', 'ac_fhx_0437_4.0', 'ac_fhx_0437_5.0', 'ac_fhx_0437_8.0', 'ac_fhx_0438_0.0', 'ac_fhx_0438_7.0', 'ac_fhx_0438_8.0', 'ac_fhx_0439_0.0', 'ac_fhx_0439_1.0', 'ac_fhx_0439_4.0', 'ac_fhx_0439_6.0', 'ac_fhx_0439_8.0', 'ac_fhx_0440_0.0', 'ac_fhx_0440_8.0', 'ac_fhx_0441_0.0', 'ac_fhx_0441_1.0', 'ac_fhx_0441_2.0', 'ac_fhx_0441_3.0', 'ac_fhx_0441_4.0', 'ac_fhx_0441_5.0', 'ac_fhx_0441_8.0', 'ac_fhx_0442_0.0', 'ac_fhx_0442_1.0', 'ac_fhx_0442_2.0', 'ac_fhx_0442_3.0', 'ac_fhx_0442_8.0', 'ac_fhx_0443_0.0', 'ac_fhx_0443_1.0', 'ac_fhx_0443_2.0', 'ac_fhx_0443_8.0', 'ac_fhx_0444_0.0', 'ac_fhx_0444_1.0', 'ac_fhx_0444_2.0', 'ac_fhx_0444_3.0', 'ac_fhx_0444_8.0', 'ac_fhx_0445_0.0', 'ac_fhx_0445_1.0', 'ac_fhx_0445_8.0', 'ac_fhx_0446_0.0', 'ac_fhx_0446_1.0', 'ac_fhx_0446_88.0', 'ac_fhx_0448_15.0', 'ac_fhx_0448_16.0', 'ac_fhx_0448_88.0', 'ac_fhx_0450_7.0', 'ac_fhx_0450_8.0', 'ac_fhx_0451_0.0', 'ac_fhx_0451_8.0', 'ac_fhx_0452_0.0', 'ac_fhx_0452_8.0', 'ac_fhx_0453_0.0', 'ac_fhx_0453_8.0', 'ac_fhx_0454_0.0', 'ac_fhx_0454_8.0', 'ac_fhx_0455_0.0', 'ac_fhx_0455_8.0', 'ac_fhx_0456_0.0', 'ac_fhx_0456_8.0', 'ac_fhx_0457_0.0', 'ac_fhx_0457_8.0', 'ac_fhx_0458_0.0', 'ac_fhx_0458_8.0', 'ac_fhx_0459_0.0', 'ac_fhx_0459_8.0', 'ac_fhx_0460_0.0', 'ac_fhx_0460_8.0', 'ac_fhx_0461_0.0', 'ac_fhx_0461_8.0', 'ac_fhx_0462_0.0', 'ac_fhx_0462_8.0', 'ac_fhx_0463_0.0', 'ac_fhx_0463_8.0', 'ac_fhx_0464_0.0', 'ac_fhx_046 ...
# Selected features: ['ao_priorhospitalization_0318', 'ac_antenataldisease_0305_0.0', 'ac_antenataldisease_0307_0.0', 'ac_antenataldisease_0309_0.0', 'ac_antenataldisease_0311_0.0', 'ac_antenataldisease_0311_1.0', 'ac_consang_0287_0.0', 'ac_mabnormalhr_0495_0.0', 'ac_mbloodgroup_0344_1.0', 'ac_mdisease_0104_0.0', 'ac_mdisease_0105_0.0', 'ac_mdisease_0188_0.0', 'ac_mdisease_0261_0.0', 'ac_mdisease_0266_0.0', 'ac_mreligion_0285_1.0', 'ac_presentation_1321_11.0', 'ac_presentation_1321_111.0', 'ac_presentationcat_1324_1.0', 'ac_radiologicix_0074_0.0', 'ac_sex_0554_1.0', 'ac_trimesteratregistration_0037_2.0']
# Working on antenatal_growth for _hie
# Dropping correlated features: ['al_magecat_0033', 'al_mweightfinal_0341', 'ao_fagecat_0376', 'ao_mdbp_0337', 'ao_meducationcat_0272', 'ao_mhctlow_0092', 'ao_mincomecat_0275', 'ao_msbp_0332', 'ao_msescat_0296', 'ao_mweightgain_0320', 'ao_personssupported_0360', 'ao_personssupportedcat_0362', 'ao_plurality_0009', 'go_headcircumferencecat_1161', 'go_lengthcat_1199', 'ac_antenataldisease_0308_8.0', 'ac_antenataldisease_0309_8.0', 'ac_antenataldisease_0310_0.0', 'ac_antenataldisease_0310_8.0', 'ac_breech_1347_7.0', 'ac_breech_1348_0.0', 'ac_breech_1348_6.0', 'ac_breech_1348_7.0', 'ac_breech_1350_0.0', 'ac_breech_1351_0.0', 'ac_breech_1352_0.0', 'ac_breech_1352_7.0', 'ac_breech_1352_8.0', 'ac_cigperday_0054_1.0', 'ac_consang_0287_8.0', 'ac_consang_0288_0.0', 'ac_consang_0288_8.0', 'ac_consang_0290_0.0', 'ac_consang_0292_0.0', 'ac_consang_0292_1.0', 'ac_fatherathome_0373_0.0', 'ac_fatherathome_0373_1.0', 'ac_fatherathome_0381_0.0', 'ac_fatherathome_0381_1.0', 'ac_fhneurology_0410_0.0', 'ac_fhneurology_0410_8.0', 'ac_fhneurology_0411_0.0', 'ac_fhneurology_0411_8.0', 'ac_fhneurology_0412_0.0', 'ac_fhneurology_0412_8.0', 'ac_fhneurology_0429_0.0', 'ac_fhneurology_0429_8.0', 'ac_fhneurology_0430_0.0', 'ac_fhneurology_0430_8.0', 'ac_fhneurology_0431_0.0', 'ac_fhneurology_0431_8.0', 'ac_fhseizures_0286_0.0', 'ac_fhseizures_0286_8.0', 'ac_fhx_0396_88.0', 'ac_fhx_0398_8.0', 'ac_fhx_0399_0.0', 'ac_fhx_0399_8.0', 'ac_fhx_0400_8.0', 'ac_fhx_0401_7.0', 'ac_fhx_0401_8.0', 'ac_fhx_0402_8.0', 'ac_fhx_0403_8.0', 'ac_fhx_0404_8.0', 'ac_fhx_0405_0.0', 'ac_fhx_0405_8.0', 'ac_fhx_0406_0.0', 'ac_fhx_0406_8.0', 'ac_fhx_0407_0.0', 'ac_fhx_0407_8.0', 'ac_fhx_0408_0.0', 'ac_fhx_0408_8.0', 'ac_fhx_0415_0.0', 'ac_fhx_0415_8.0', 'ac_fhx_0416_0.0', 'ac_fhx_0416_8.0', 'ac_fhx_0417_8.0', 'ac_fhx_0418_0.0', 'ac_fhx_0418_8.0', 'ac_fhx_0419_0.0', 'ac_fhx_0419_8.0', 'ac_fhx_0420_0.0', 'ac_fhx_0420_8.0', 'ac_fhx_0421_0.0', 'ac_fhx_0421_8.0', 'ac_fhx_0422_0.0', 'ac_fhx_0422_8.0', 'ac_fhx_0423_0.0', 'ac_fhx_0423_8.0', 'ac_fhx_0424_0.0', 'ac_fhx_0424_8.0', 'ac_fhx_0425_0.0', 'ac_fhx_0425_8.0', 'ac_fhx_0426_0.0', 'ac_fhx_0426_8.0', 'ac_fhx_0427_0.0', 'ac_fhx_0427_8.0', 'ac_fhx_0432_0.0', 'ac_fhx_0432_1.0', 'ac_fhx_0432_2.0', 'ac_fhx_0432_8.0', 'ac_fhx_0433_0.0', 'ac_fhx_0433_1.0', 'ac_fhx_0433_2.0', 'ac_fhx_0433_3.0', 'ac_fhx_0433_5.0', 'ac_fhx_0433_6.0', 'ac_fhx_0433_8.0', 'ac_fhx_0434_3.0', 'ac_fhx_0434_5.0', 'ac_fhx_0434_7.0', 'ac_fhx_0434_8.0', 'ac_fhx_0435_0.0', 'ac_fhx_0435_1.0', 'ac_fhx_0435_3.0', 'ac_fhx_0435_7.0', 'ac_fhx_0435_8.0', 'ac_fhx_0436_0.0', 'ac_fhx_0436_1.0', 'ac_fhx_0436_2.0', 'ac_fhx_0436_4.0', 'ac_fhx_0436_8.0', 'ac_fhx_0437_0.0', 'ac_fhx_0437_1.0', 'ac_fhx_0437_2.0', 'ac_fhx_0437_3.0', 'ac_fhx_0437_4.0', 'ac_fhx_0437_5.0', 'ac_fhx_0437_8.0', 'ac_fhx_0438_0.0', 'ac_fhx_0438_6.0', 'ac_fhx_0438_7.0', 'ac_fhx_0438_8.0', 'ac_fhx_0439_0.0', 'ac_fhx_0439_1.0', 'ac_fhx_0439_2.0', 'ac_fhx_0439_4.0', 'ac_fhx_0439_6.0', 'ac_fhx_0439_8.0', 'ac_fhx_0440_0.0', 'ac_fhx_0440_8.0', 'ac_fhx_0441_0.0', 'ac_fhx_0441_1.0', 'ac_fhx_0441_2.0', 'ac_fhx_0441_3.0', 'ac_fhx_0441_4.0', 'ac_fhx_0441_5.0', 'ac_fhx_0441_8.0', 'ac_fhx_0442_0.0', 'ac_fhx_0442_1.0', 'ac_fhx_0442_2.0', 'ac_fhx_0442_3.0', 'ac_fhx_0442_8.0', 'ac_fhx_0443_0.0', 'ac_fhx_0443_1.0', 'ac_fhx_0443_2.0', 'ac_fhx_0443_8.0', 'ac_fhx_0444_0.0', 'ac_fhx_0444_2.0', 'ac_fhx_0444_3.0', 'ac_fhx_0444_8.0', 'ac_fhx_0445_0.0', 'ac_fhx_0445_2.0', 'ac_fhx_0445_8.0', 'ac_fhx_0446_0.0', 'ac_fhx_0446_88.0', 'ac_fhx_0448_1.0', 'ac_fhx_0448_8.0', 'ac_fhx_0448_11.0', 'ac_fhx_0448_15.0', 'ac_fhx_0448_16.0', 'ac_fhx_0448_88.0', 'ac_fhx_0450_7.0', 'ac_fhx_0450_8.0', 'ac_fhx_0451_0.0', 'ac_fhx_0451_8.0', 'ac_fhx_0452_0.0', 'ac_fhx_0452_8.0', 'ac_fhx_0453_0.0', 'ac_fhx_0453_8.0', 'ac_fhx_0454_0.0', 'ac_fhx_0454_8.0', 'ac_fhx_0455_0.0', 'ac_fhx_0455_8.0', 'ac_fhx_0456_0.0', 'ac_fhx_0456_8.0', 'ac_fhx_0457_0.0', 'ac_fhx_0457_8.0', 'ac_fhx_0458_0.0', 'ac_fhx_0458_8.0', 'ac_fhx_0459_0.0', 'ac_fhx_0459_8.0', 'ac_fhx_0460_0.0', 'ac_fhx_04 ...
# Selected features: ['al_parity_0046', 'ac_antenataldisease_0307_0.0', 'ac_fhx_0398_0.0', 'ac_fhx_0401_1.0', 'ac_foccupation_0385_60.0', 'ac_mabnormalhr_0495_0.0', 'ac_mbirthplace_0278_1.0', 'ac_mbloodgroup_0344_1.0', 'ac_mdisease_0104_0.0', 'ac_mdisease_0105_7.0', 'ac_mdisease_0188_0.0', 'ac_presentation_1321_11.0', 'ac_presentation_1321_111.0', 'ac_presentationcat_1324_1.0', 'ac_race_0303_1', 'ac_sex_0554_1.0']
# Working on antenatal_growth for _lapgar
# Dropping correlated features: ['al_magecat_0033', 'al_mweightfinal_0341', 'ao_fagecat_0376', 'ao_mdbp_0337', 'ao_meducationcat_0272', 'ao_mhctlow_0092', 'ao_mincomecat_0275', 'ao_msbp_0332', 'ao_msescat_0296', 'ao_mweightgain_0320', 'ao_personssupportedcat_0362', 'ao_plurality_0009', 'go_headcircumferencecat_1161', 'go_lengthcat_1199', 'ac_antenataldisease_0308_8.0', 'ac_antenataldisease_0310_0.0', 'ac_antenataldisease_0310_8.0', 'ac_breech_1347_7.0', 'ac_breech_1348_0.0', 'ac_breech_1348_6.0', 'ac_breech_1348_7.0', 'ac_breech_1350_0.0', 'ac_breech_1351_0.0', 'ac_breech_1352_0.0', 'ac_breech_1352_7.0', 'ac_breech_1352_8.0', 'ac_cigperday_0054_1.0', 'ac_consang_0287_8.0', 'ac_consang_0288_0.0', 'ac_consang_0288_8.0', 'ac_consang_0289_8.0', 'ac_consang_0290_0.0', 'ac_consang_0292_0.0', 'ac_fatherathome_0373_0.0', 'ac_fatherathome_0373_1.0', 'ac_fatherathome_0381_0.0', 'ac_fatherathome_0381_1.0', 'ac_fhneurology_0410_0.0', 'ac_fhneurology_0410_8.0', 'ac_fhneurology_0411_0.0', 'ac_fhneurology_0411_8.0', 'ac_fhneurology_0412_0.0', 'ac_fhneurology_0412_8.0', 'ac_fhneurology_0429_0.0', 'ac_fhneurology_0429_8.0', 'ac_fhneurology_0430_0.0', 'ac_fhneurology_0430_8.0', 'ac_fhneurology_0431_0.0', 'ac_fhneurology_0431_8.0', 'ac_fhseizures_0286_0.0', 'ac_fhseizures_0286_8.0', 'ac_fhx_0396_88.0', 'ac_fhx_0398_8.0', 'ac_fhx_0399_0.0', 'ac_fhx_0399_8.0', 'ac_fhx_0400_8.0', 'ac_fhx_0401_8.0', 'ac_fhx_0402_8.0', 'ac_fhx_0403_8.0', 'ac_fhx_0404_8.0', 'ac_fhx_0405_0.0', 'ac_fhx_0405_8.0', 'ac_fhx_0406_0.0', 'ac_fhx_0406_8.0', 'ac_fhx_0407_0.0', 'ac_fhx_0407_8.0', 'ac_fhx_0408_0.0', 'ac_fhx_0408_8.0', 'ac_fhx_0415_0.0', 'ac_fhx_0415_8.0', 'ac_fhx_0416_0.0', 'ac_fhx_0416_8.0', 'ac_fhx_0417_8.0', 'ac_fhx_0418_0.0', 'ac_fhx_0418_8.0', 'ac_fhx_0419_0.0', 'ac_fhx_0419_8.0', 'ac_fhx_0420_0.0', 'ac_fhx_0420_8.0', 'ac_fhx_0421_0.0', 'ac_fhx_0421_8.0', 'ac_fhx_0422_0.0', 'ac_fhx_0422_8.0', 'ac_fhx_0423_0.0', 'ac_fhx_0423_8.0', 'ac_fhx_0424_0.0', 'ac_fhx_0424_8.0', 'ac_fhx_0425_0.0', 'ac_fhx_0425_8.0', 'ac_fhx_0426_0.0', 'ac_fhx_0426_8.0', 'ac_fhx_0427_0.0', 'ac_fhx_0427_8.0', 'ac_fhx_0432_0.0', 'ac_fhx_0432_1.0', 'ac_fhx_0432_2.0', 'ac_fhx_0432_4.0', 'ac_fhx_0432_8.0', 'ac_fhx_0433_0.0', 'ac_fhx_0433_1.0', 'ac_fhx_0433_2.0', 'ac_fhx_0433_3.0', 'ac_fhx_0433_5.0', 'ac_fhx_0433_6.0', 'ac_fhx_0433_8.0', 'ac_fhx_0434_1.0', 'ac_fhx_0434_2.0', 'ac_fhx_0434_3.0', 'ac_fhx_0434_5.0', 'ac_fhx_0434_7.0', 'ac_fhx_0434_8.0', 'ac_fhx_0435_0.0', 'ac_fhx_0435_5.0', 'ac_fhx_0435_7.0', 'ac_fhx_0435_8.0', 'ac_fhx_0436_0.0', 'ac_fhx_0436_1.0', 'ac_fhx_0436_2.0', 'ac_fhx_0436_4.0', 'ac_fhx_0436_8.0', 'ac_fhx_0437_1.0', 'ac_fhx_0437_2.0', 'ac_fhx_0437_3.0', 'ac_fhx_0437_4.0', 'ac_fhx_0437_5.0', 'ac_fhx_0437_8.0', 'ac_fhx_0438_0.0', 'ac_fhx_0438_7.0', 'ac_fhx_0438_8.0', 'ac_fhx_0439_0.0', 'ac_fhx_0439_1.0', 'ac_fhx_0439_3.0', 'ac_fhx_0439_4.0', 'ac_fhx_0439_6.0', 'ac_fhx_0439_8.0', 'ac_fhx_0440_0.0', 'ac_fhx_0440_1.0', 'ac_fhx_0440_2.0', 'ac_fhx_0440_8.0', 'ac_fhx_0441_0.0', 'ac_fhx_0441_1.0', 'ac_fhx_0441_2.0', 'ac_fhx_0441_3.0', 'ac_fhx_0441_4.0', 'ac_fhx_0441_5.0', 'ac_fhx_0441_8.0', 'ac_fhx_0442_0.0', 'ac_fhx_0442_1.0', 'ac_fhx_0442_2.0', 'ac_fhx_0442_3.0', 'ac_fhx_0442_8.0', 'ac_fhx_0443_0.0', 'ac_fhx_0443_1.0', 'ac_fhx_0443_2.0', 'ac_fhx_0443_8.0', 'ac_fhx_0444_0.0', 'ac_fhx_0444_1.0', 'ac_fhx_0444_2.0', 'ac_fhx_0444_3.0', 'ac_fhx_0444_8.0', 'ac_fhx_0445_0.0', 'ac_fhx_0445_8.0', 'ac_fhx_0446_0.0', 'ac_fhx_0446_1.0', 'ac_fhx_0446_88.0', 'ac_fhx_0448_1.0', 'ac_fhx_0448_8.0', 'ac_fhx_0448_11.0', 'ac_fhx_0448_15.0', 'ac_fhx_0448_16.0', 'ac_fhx_0448_88.0', 'ac_fhx_0450_7.0', 'ac_fhx_0450_8.0', 'ac_fhx_0451_0.0', 'ac_fhx_0451_8.0', 'ac_fhx_0452_0.0', 'ac_fhx_0452_8.0', 'ac_fhx_0453_0.0', 'ac_fhx_0453_8.0', 'ac_fhx_0454_0.0', 'ac_fhx_0454_8.0', 'ac_fhx_0455_0.0', 'ac_fhx_0455_8.0', 'ac_fhx_0456_0.0', 'ac_fhx_0456_8.0', 'ac_fhx_0457_0.0', 'ac_fhx_0457_8.0', 'ac_fhx_0458_0.0', 'ac_fhx_0458_8.0', 'ac_fhx_0459_0.0', 'ac_fhx_0459_8.0', 'ac_fhx_0460_0.0', 'ac_fhx_0460_8.0', 'ac_fhx_0461_ ...
# Selected features: ['ac_antenataldisease_0307_0.0', 'ac_antenataldisease_0307_4.0', 'ac_antenataldisease_0309_0.0', 'ac_antenataldisease_0311_0.0', 'ac_antenataldisease_0311_1.0', 'ac_cigperday_0054_0.0', 'ac_fhx_0435_1.0', 'ac_foccupationcat_0387_2.0', 'ac_mabnormalhr_0495_0.0', 'ac_mdisease_0104_0.0', 'ac_mdisease_0262_0.0', 'ac_moccupation_0363_72.0', 'ac_moccupationcat_0365_3.0', 'ac_mreligion_0285_1.0', 'ac_presentation_1321_11.0', 'ac_presentation_1321_111.0', 'ac_presentationcat_1324_1.0', 'ac_sex_0554_1.0', 'ac_trimesteratregistration_0037_3.0']
# Working on antenatal_growth for _perinataldeath
